# %%
import random

# %%
random.randint(-90,90)
# Out:
# 38

# %%
random.random()
# Out:
# 0.17999661596560035

# %%
random_number = random.randint(-90,90) + random.random()
random_number
# Out:
# -72.74632235703693

# %%
random.randrange(-90, 90, step=3)
# Out:
# -21

# %%
random.uniform(-90, 90)
# Out:
# 8.637304300629069

# %%
#import the numPy module
import numpy as np

# %%
np.random.uniform(-90,90, size=50)
# Out:
# array([-11.56912691, -82.7169429 ,  73.91461528,  54.48097588,
#         31.88579269, -87.37157526, -45.64611114,  60.34508985,
#         79.23412144,  26.76392914,  76.39882645,  55.4271816 ,
#         41.60842725, -27.07278106,  88.43919442,  27.1534955 ,
#        -88.18957773,  21.06729625, -32.96503839, -16.84489686,
#         70.78840031,  61.00742012,  19.31280591,  -9.86624287,
#        -73.12543262, -32.55201728,  62.37117174,  87.23557341,
#         81.96548848,  74.92508283, -25.80571587,  13.19998582,
#        -25.66880907, -80.82843689,  63.71494704,  -2.52090929,
#         72.76424813,   2.00191107,  65.88372452,  -2.42208202,
#         17.86991185,  85.43407114,  49.63987646, -81.48502336,
#         45.59893667, -10.99036335, -17.99988684, -44.31845265,
#          9.54515607, -12.4172808 ])

# %%
#import timeit
import timeit

# %%
# %timeit np.random.uniform(-90,90, size=1500)
# Out:
# 12.4 µs ± 77.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.02 ms ± 3.19 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
latitudes = []
x = 0
while x < 1501:
    random_lat = np.random.uniform(-90, 90) 
    latitudes.append(random_lat)
    x += 1
# Call the function with 1500.
# %timeit latitudes
# Out:
# 16.9 ns ± 0.156 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)
